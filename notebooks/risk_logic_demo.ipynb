# %%
import pandas as pd
from scripts.risk_scoring import calculate_risk_score

sample = {"delinquency_rate": 0.05, "collateral_ratio": 0.8, "portfolio_concentration": 0.3}
score = calculate_risk_score(**sample)
print(f'Computed risk score: {score:.2f}')
